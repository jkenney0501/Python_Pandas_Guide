# %% [markdown]
# ### Install the DataReader since we are using a onlne source

# %%
pip install pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pandas_datareader import data
import matplotlib.pyplot as plt

# to display viz inline
# %matplotlib inline

# %% [markdown]
# ### Rendering data in a visual representation
# - Basic ways to use Pandas
# - import matplotlib for later use
# - See the matplotlib docs for additonal useage here: <a>https://matplotlib.org/stable/plot_types/index</a>

# %%
# render a line chart with stock data for black berry - use data reader but first create a data frame
# provide 4 paramters using data reader: name, source, start date, end date
bb = data.DataReader(name = 'BB', data_source = 'yahoo', start = '2007-01-01', end = '2020-12-31')

bb.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2007-01-03  44.026665  41.704666  43.084999  42.849998  34692849.0  42.849998
# 2007-01-04  46.316002  42.423332  42.953335  46.189999  45586929.0  46.189999
# 2007-01-05  47.306667  45.166664  45.500000  47.099998  41073453.0  47.099998
# 2007-01-08  48.410000  46.606667  47.283333  47.386665  38450475.0  47.386665
# 2007-01-09  47.666664  43.263332  47.570000  43.666664  73547715.0  43.666664

# %%
# render plot - this is kind of ugly.... you cant see anything other than volumne
bb.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# target specific columns using y = 
# this shows us the close price on y with the year on x
bb.plot(y='Close')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# use a series to plot the high - results in the same as above
bb['High'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 2 cols with high and close and alegend key to distinguish the two (they are simliar)
bb[['High', 'Close']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Modify plot aesthetics
# - we will access a nested package called "style" by adding .style
# - to see the various themes for style use: <b> plt.style.available</b>

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# set the style - you can put this at the start under imports to set the style for all your graphs
plt.style.use('fivethirtyeight')

# %%
bb.plot(y='Close')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Creating Bar Charts

# %%
plt.style.use('seaborn-whitegrid')

# %%
# ideal for showing counts in catagories, create a function to gather category and then use apply for func and counts
def category_perf(price):
    if price <= 10:
        return 'Poor'
    elif price <= 50:
        return 'Satisfactory'
    else:
        return 'High Performing'

# %%
# create the summary to visually represent- apply func above and method chain value counts to summarize
# you have to apply a parameter to the plot explicitly! Default is line
bb['Close'].apply(category_perf).value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# create the above but horzontally by using barh
bb['Close'].apply(category_perf).value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Creating Scatter Plots

# %%
# set the style for the scatter plot
plt.style.use('seaborn-muted')

# %%
# Soon to come

# %% [markdown]
# #### Create a pie chart
# - To find proporations
# - Use a new function to show 2 categories: less than average or above average.

# %%
def performance(price):
    if price <= bb['Close'].mean():
        return 'Below Average'
    else:
        return 'Above Average'

# %%
bb['Close'].apply(performance).value_counts()
# Out:
# Below Average    2388
# Above Average    1137
# Name: Close, dtype: int64

# %%
# create the pie - add legen by using legend=True you don need this here
bb['Close'].apply(performance).value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Close'>
